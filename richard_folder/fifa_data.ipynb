# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
file = "./raw_data.csv"
pd_file = pd.read_csv(file, encoding = "utf-8" )
# Out:
# /Users/richardphilipose/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd_file
# Out:
#            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# 2      Coventry City   71  CAM  CAM RM RW LM
# ...

# %%
engine = create_engine('sqlite:///fifa_dataset.db', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2021-01-23 12:19:40,891 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-01-23 12:19:40,891 INFO sqlalchemy.engine.base.Engine ()
# 2021-01-23 12:19:40,894 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-01-23 12:19:40,895 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table = "fifa_data"
clean_data.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
# Out:
# 2021-01-23 12:19:47,321 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("fifa_data")
# 2021-01-23 12:19:47,323 INFO sqlalchemy.engine.base.Engine ()
# 2021-01-23 12:19:47,325 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("fifa_data")
# 2021-01-23 12:19:47,326 INFO sqlalchemy.engine.base.Engine ()
# 2021-01-23 12:19:47,366 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE fifa_data (
# 	"index" BIGINT,
# 	"ID" BIGINT,
# 	"Name" TEXT,
# 	"Age" BIGINT,
# 	"OVA" BIGINT,
# 	"Nationality" TEXT,
# 	"Club" TEXT,
# 	"BOV" BIGINT,
# 	"BP" TEXT,
# 	"Position" TEXT,
# 	"Player Photo" TEXT,
# 	"Club Logo" TEXT,
# 	"Flag Photo" TEXT,
# 	"POT" BIGINT,
# 	"Team & Contract" TEXT,
# 	"Height" TEXT,
# 	"Weight" TEXT,
# 	foot TEXT,
# 	"Growth" BIGINT,
# 	"Joined" TEXT,
# 	"Loan Date End" TEXT,
# 	"Value" TEXT,
# 	"Wage" TEXT,
# 	"Release Clause" TEXT,
# 	"Contract" TEXT,
# 	"Attacking" BIGINT,
# 	"Crossing" BIGINT,
# 	"Finishing" BIGINT,
# 	"Heading Accuracy" BIGINT,
# ...

# %%
sqlite_connection.close()

# %%
## Kim's Chart

# %%
file = "./fifa21.csv"
kim_file = pd.read_csv(file, encoding = "utf-8" )

# %%
engine = create_engine('sqlite:///kim_dataset.db', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2021-01-26 18:25:56,870 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-01-26 18:25:56,871 INFO sqlalchemy.engine.base.Engine ()
# 2021-01-26 18:25:56,873 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-01-26 18:25:56,874 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table = "kim_data"
kim_file.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
# Out:
# 2021-01-26 18:29:10,144 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("kim_data")
# 2021-01-26 18:29:10,146 INFO sqlalchemy.engine.base.Engine ()
# 2021-01-26 18:29:10,150 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("kim_data")
# 2021-01-26 18:29:10,152 INFO sqlalchemy.engine.base.Engine ()
# 2021-01-26 18:29:10,161 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE kim_data (
# 	"index" BIGINT,
# 	name TEXT,
# 	age BIGINT,
# 	overall BIGINT,
# 	nationality TEXT,
# 	club TEXT,
# 	bestposition TEXT,
# 	playerphoto TEXT,
# 	flagphoto TEXT,
# 	potential BIGINT,
# 	height TEXT,
# 	inches BIGINT,
# 	weight BIGINT,
# 	bmi FLOAT,
# 	foot TEXT,
# 	value FLOAT,
# 	wage FLOAT,
# 	totalstats BIGINT,
# 	basestats BIGINT,
# 	attacking BIGINT,
# 	skill BIGINT,
# 	movement BIGINT,
# 	power BIGINT,
# 	mentality BIGINT,
# 	defending BIGINT,
# 	goalkeeping BIGINT
# )
#
#
# 2021-01-26 18:29:10,162 INFO sqlalchemy.engine.base.Engine ()
# ...
